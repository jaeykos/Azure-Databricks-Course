# %% [markdown]
# # Lab Exercise:
# ## Washingtons and Marthas

# %% [markdown]
# -sandbox
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/wiki-book/general/logo_spark_tiny.png) Instructions
#
# This data was captured in the August before the 2016 US presidential election.
#
# As a result, articles about the candidates were very popular.
#
# For this exercise, you will...
# 0. Filter the result to the **en** Wikipedia project.
# 0. Find all the articles where the name of the article **ends** with **_Washington** (presumably "George Washington", "Martha Washington", etc)
# 0. Return all records as an array to the Driver.
# 0. Assign your array of Washingtons (the return value of your action) to the variable `washingtons`.
# 0. Calculate the sum of requests for the Washingtons and assign it to the variable `totalWashingtons`. <br/>
# <img alt="Hint" title="Hint" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-light-bulb.svg"/>&nbsp;**Hint:** We've not yet covered `DataFrame` aggregation techniques, so for this exercise use the array of records you have just obtained.
#
# ** Bonus **
#
# Repeat the exercise for the Marthas
# 0. Filter the result to the **en** Wikipedia project.
# 0. Find all the articles where the name of the article **starts** with **Martha_** (presumably "Martha Washington", "Martha Graham", etc)
# 0. Return all records as an array to the Driver.
# 0. Assign your array of Marthas (the return value of your action) to the variable `marthas`.
# 0. Calculate the sum of requests for the Marthas and assign it to the variable `totalMarthas`.<br/>
# <img alt="Hint" title="Hint" style="vertical-align: text-bottom; position: relative; height:1.75em; top:0.3em" src="https://files.training.databricks.com/static/images/icon-light-bulb.svg"/>&nbsp;**Hint:** We've not yet covered `DataFrame` aggregation techniques, so for this exercise use the array of records you have just obtained.
# 0. But you cannot do it the same way twice:
#    * In the filter, don't use the same conditional method as the one used for the Washingtons.
#    * Don't use the same action as used for the Washingtons.
#
# **Testing**
#
# Run the last cell to verify that your results are correct.
#
# **Hints**
# * <img alt="Caution" title="Caution" style="vertical-align: text-bottom; position: relative; height:1.3em; top:0.0em" src="https://files.training.databricks.com/static/images/icon-warning.svg"/> Make sure to include the underscore in the condition.
# * The actions we've explored for extracting data include:
#   * `first()`
#   * `collect()`
#   * `head()`
#   * `take(n)`
# * The conditional methods used with a `filter(..)` include:
#   * equals
#   * not-equals
#   * starts-with
#   * and there are others - remember, the `DataFrames` API is built upon an SQL engine.
# * There shouldn't be more than 1000 records for either the Washingtons or the Marthas

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Getting Started
#
# Run the following cell to configure our "classroom."

# %%
# %run "./Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Initialized classroom variables & functions...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Datasets are already mounted to <b>/mnt/training</b> from <b>wasbs://training@dbtraineastus.blob.core.windows.net/</b>
# Created user-specific database
# Using the database <b style="color:green">jaeykos_hotmail_com_db</b>.
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# All done!

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/wiki-book/general/logo_spark_tiny.png) Show Your Work

# %%
(source, sasEntity, sasToken) = getAzureDataSource()
spark.conf.set(sasEntity, sasToken)

parquetDir = source + "/wikipedia/pagecounts/staging_parquet_en_only_clean/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# 0. Filter the result to the **en** Wikipedia project.
# 0. Find all the articles where the name of the article **ends** with **_Washington** (presumably "George Washington", "Martha Washington", etc)
# 0. Return all records as an array to the Driver.
# 0. Assign your array of Washingtons (the return value of your action) to the variable `washingtons`.
# 0. Calculate the sum of requests for the Washingtons and assign it to the variable `totalWashingtons`
washingtons = (spark  # Our SparkSession & Entry Point
  .read                     # Our DataFrameReader
  .parquet(parquetDir)     # Returns an instance of DataFrame
  .cache()                  # cache the data
  .where( "article  like '%_Washington'" )
)               

washingtons = (washingtons
  .collect()           # The action returning all records in the DataFrame
)

totalWashingtons = 0

for washington in washingtons:
  totalWashingtons +=  washington['requests']
  
display(washingtons)
  
print("Total Washingtons: {0:,}".format( len(washingtons) ))
print("Total Washington Requests: {0:,}".format( totalWashingtons ))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>project</th><th>article</th><th>requests</th><th>bytes_served</th></tr></thead><tbody><tr><td>en</td><td>Adolphus_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Bangor_Base,_Washington</td><td>3</td><td>0</td></tr><tr><td>en</td><td>Bellevue,_Washington</td><td>17</td><td>0</td></tr><tr><td>en</td><td>Benton_County,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Billy_Jack_Goes_to_Washington</td><td>2</td><td>0</td></tr><tr><td>en</td><td>Category:Buildings_and_structures_in_Tacoma,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Category:Universities_and_colleges_in_Tacoma,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Chehalis,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Cheney,_Washington</td><td>2</td><td>0</td></tr><tr><td>en</td><td>Citizens_for_Responsibility_and_Ethics_in_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Clearwater,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Cottage_Lake,_Washington</td><td>3</td><td>0</td></tr><tr><td>en</td><td>Duvall,_Washington</td><td>2</td><td>0</td></tr><tr><td>en</td><td>Eastern_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Edmonds,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Embassy_of_Germany_in_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>First_inauguration_of_George_Washington</td><td>710</td><td>0</td></tr><tr><td>en</td><td>Fobes_Hill,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Fox_Island,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Governor_of_Washington</td><td>4</td><td>0</td></tr><tr><td>en</td><td>Harold_Washington</td><td>3</td><td>0</td></tr><tr><td>en</td><td>International_Shoe_v._Washington</td><td>2</td><td>0</td></tr><tr><td>en</td><td>Islamic_Center_of_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Jascha_Washington</td><td>3</td><td>0</td></tr><tr><td>en</td><td>Kermit_Alan_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Kerry_Washington</td><td>55</td><td>0</td></tr><tr><td>en</td><td>Kirkland,_Washington</td><td>7</td><td>0</td></tr><tr><td>en</td><td>Lacey,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Leon_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>List_of_United_States_Representatives_from_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>List_of_airports_in_Washington</td><td>5</td><td>0</td></tr><tr><td>en</td><td>List_of_people_from_Spokane,_Washington</td><td>2</td><td>0</td></tr><tr><td>en</td><td>List_of_places_named_for_George_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Mary_Ball_Washington</td><td>8</td><td>0</td></tr><tr><td>en</td><td>Mazama,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Military_career_of_George_Washington</td><td>13</td><td>0</td></tr><tr><td>en</td><td>Molson,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Morton,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>NAF_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Nagrom,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Okanogan,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Oroville,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Paul_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Port_Orchard,_Washington</td><td>5</td><td>0</td></tr><tr><td>en</td><td>Portal:Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Religious_views_of_George_Washington</td><td>3</td><td>0</td></tr><tr><td>en</td><td>Riverton,_Washington</td><td>2</td><td>0</td></tr><tr><td>en</td><td>Roslyn,_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>SS_George_Washington</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Samuel_Washington</td><td>2</td><td>0</td></tr><tr><td>en</td><td>San_Juan_County,_Washington</td><td>4</td><td>0</td></tr><tr><td>en</ ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Total Washingtons: 768
# Total Washington Requests: 5,931
# </div>

# %%
# TODO
# 0. Filter the result to the **en** Wikipedia project.
# 0. Find all the articles where the name of the article **starts** with **Martha_** (presumably "Martha Washington", "Martha Graham", etc)
# 0. Return all records as an array to the Driver.
# 0. Assign your array of Marthas (the return value of your action) to the variable `marthas`.
# 0. Calculate the sum of requests for the Marthas and assign it to the variable `totalMarthas`.

marthas = (spark  # Our SparkSession & Entry Point
  .read                     # Our DataFrameReader
  .parquet(parquetDir)     # Returns an instance of DataFrame
  .cache()                  # cache the data
  .where( "project= 'en'" and "article like 'Martha_%'")
  .collect()
)    

totalMarthas = 0

for martha in marthas:
  totalMarthas += martha['requests']

display(marthas)

print("Total Marthas: {0:,}".format( len(marthas) ))
print("Total Martha Requests: {0:,}".format( totalMarthas ))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>project</th><th>article</th><th>requests</th><th>bytes_served</th></tr></thead><tbody><tr><td>en</td><td>Martha,_Inc.:_The_Story_of_Martha_Stewart</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_Argerich</td><td>13</td><td>0</td></tr><tr><td>en</td><td>Martha_Bunting</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_Cecilia</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_Coston</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_Ellen_Young_Truman</td><td>6</td><td>0</td></tr><tr><td>en</td><td>Martha_Gellhorn_Prize_for_Journalism</td><td>2</td><td>0</td></tr><tr><td>en</td><td>Martha_Hunt</td><td>8</td><td>0</td></tr><tr><td>en</td><td>Martha_Kane</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_Lane_Fox,_Baroness_Lane-Fox_of_Soho</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_MacIsaac</td><td>4</td><td>0</td></tr><tr><td>en</td><td>Martha_McSally</td><td>7</td><td>0</td></tr><tr><td>en</td><td>Martha_Nussbaum</td><td>21</td><td>0</td></tr><tr><td>en</td><td>Martha_Roby</td><td>9</td><td>0</td></tr><tr><td>en</td><td>Martha_Sleeper</td><td>2</td><td>0</td></tr><tr><td>en</td><td>Martha_Stewart_Living_Omnimedia</td><td>3</td><td>0</td></tr><tr><td>en</td><td>Martha_Wadsworth_Brewster</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_Wayles_Skelton</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_and_Mary_Magdalene_(Caravaggio)</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Marthatown,_West_Virginia</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>Martha_(band)</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>Martha_Beck</td><td>2</td><td>0</td></tr><tr><td>en.m</td><td>Martha_Chen</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>Martha_Custis_Washington</td><td>2</td><td>0</td></tr><tr><td>en.m</td><td>Martha_Gellhorn</td><td>2</td><td>0</td></tr><tr><td>en.m</td><td>Martha_Higareda</td><td>2</td><td>0</td></tr><tr><td>en.m</td><td>Martha_Jefferson</td><td>15</td><td>0</td></tr><tr><td>en.m</td><td>Martha_Lane_Fox</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>Martha_Marcy_May_Marlene</td><td>6</td><td>0</td></tr><tr><td>en.m</td><td>Martha_O'Driscoll</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>Martha_Raye</td><td>3</td><td>0</td></tr><tr><td>en.m</td><td>Martha_Rountree</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>Martha_Thompson</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>Martha_Wayles_Skelton</td><td>1</td><td>0</td></tr><tr><td>en.m</td><td>Marthanda_Varma</td><td>4</td><td>0</td></tr><tr><td>en.zero</td><td>Martha_McSally</td><td>2</td><td>0</td></tr><tr><td>en</td><td>Martha's_Vineyard_Sign_Language</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_Albertson_Fineman</td><td>3</td><td>0</td></tr><tr><td>en</td><td>Martha_Bernays</td><td>4</td><td>0</td></tr><tr><td>en</td><td>Martha_Carey_Thomas</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_Coolidge</td><td>2</td><td>0</td></tr><tr><td>en</td><td>Martha_Dodd</td><td>5</td><td>0</td></tr><tr><td>en</td><td>Martha_Fuller_Clark</td><td>2</td><td>0</td></tr><tr><td>en</td><td>Martha_Hedman</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_Johansson</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_Ladly</td><td>2</td><td>0</td></tr><tr><td>en</td><td>Martha_Logan</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_Masters_(House)</td><td>4</td><td>0</td></tr><tr><td>en</td><td>Martha_Munizzi</td><td>2</td><td>0</td></tr><tr><td>en</td><td>Martha_Raye</td><td>5</td><td>0</td></tr><tr><td>en</td><td>Martha_Sharp</td><td>2</td><td>0</td></tr><tr><td>en</td><td>Martha_Stettler</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_Vasconcellos</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_Wash_(album)</td><td>1</td><td>0</td></tr><tr><td>en</td><td>Martha_Wise</td><td>3</td><td>0</td></tr><tr><td>en</td><td>Marthanda_Varma_(film)</td><td>1</td><td>0</td></tr ...
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Total Marthas: 287
# Total Martha Requests: 1,549
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/wiki-book/general/logo_spark_tiny.png) Verify Your Work
# Run the following cell to verify that your `DataFrame` was created properly.

# %%
print("Total Washingtons: {0:,}".format( len(washingtons) ))
print("Total Washington Requests: {0:,}".format( totalWashingtons ))

expectedCount = 768
assert len(washingtons) == expectedCount, "Expected " + str(expectedCount) + " articles but found " + str( len(washingtons) )

expectedTotal = 5931
assert totalWashingtons == expectedTotal, "Expected " + str(expectedTotal) + " requests but found " + str(totalWashingtons)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Total Washingtons: 768
# Total Washington Requests: 5,931
# </div>

# %%
print("Total Marthas: {0:,}".format( len(marthas) ))
print("Total Marthas Requests: {0:,}".format( totalMarthas ))

expectedCount = 287
assert len(marthas) == expectedCount, "Expected " + str(expectedCount) + " articles but found " + str( len(marthas) )

expectedTotal = 1549
assert totalMarthas == expectedTotal, "Expected " + str(expectedTotal) + " requests but found " + str(totalMarthas)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Total Marthas: 287
# Total Marthas Requests: 1,549
# </div>
